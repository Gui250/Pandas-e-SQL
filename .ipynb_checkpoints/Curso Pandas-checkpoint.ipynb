# %%
import pandas as pd
df = pd.DataFrame({'col1': [1,2,3,4], 'col2': [444,555,666,444], 'col3': ['abc', 'def', 'ghi', 'xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      int64
#  1   col2    4 non-null      int64
#  2   col3    4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.memory_usage()
# Out:
# Index    132
# col1      32
# col2      32
# col3      32
# dtype: int64

# %% [markdown]
# ## Informações sobre valores exclusivos

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique() # retorna os valores unicos do dataframe
# Out:
# array([444, 555, 666], dtype=int64)

# %%
df['col2'].nunique() # quantidade de valores unicos no dataframe
# Out:
# 3

# %%
df['col2'].value_counts().index
# Out:
# Index([444, 555, 666], dtype='int64', name='col2')

# %% [markdown]
# # Aplicando funções

# %%
def comp(x):
    return x ** 2 + 3

# %%
df['col1'].apply(comp)  # aplica a função no dataframe
# Out:
# 0     4
# 1     7
# 2    12
# 3    19
# Name: col1, dtype: int64

# %%
df['col1_calc'] = df['col1'].apply(comp)

# %%
df
# Out:
#    col1  col2 col3  col1_calc
# 0     1   444  abc          4
# 1     2   555  def          7
# 2     3   666  ghi         12
# 3     4   444  xyz         19

# %%
df['col1'].apply(lambda x: x ** 2 + 3)
# Out:
# 0     4
# 1     7
# 2    12
# 3    19
# Name: col1, dtype: int64

# %%
df['col1'].sum()
# Out:
# 10

# %%
df['col1'].mean()
# Out:
# 2.5

# %%
df['col1'].product()
# Out:
# 24

# %%
df['col1'].std()
# Out:
# 1.2909944487358056
